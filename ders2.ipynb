# %%
print("Merhaba IGU MYO YZ Dersim 2.Hafta") #YAPAY ZEKA DERSI
# Out:
# Merhaba IGU MYO YZ Dersim 2.Hafta

# %%
import sys #import pyhton programlama dilinde yazılıma kütüphane eklemeye yarar kod
print(sys.version)
# Out:
# 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]

# %%
from google.colab import drive #google colab - drive baglantısı
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/Yapay_Zeka_Dersim')
#!pwd #bize kodun çıktısını dosya yolu olarak veren kod bloğudur.

# %%
import pandas as pd
#Barisin ders notları ve bilgileri
data = {'Ders' : ['Algoritma','PcProgramlama','Elektronik-2','AviyonikSistemler'],'Not':[95,100,65,90] }
#Veriyi Bir DataFramee dönüştürür
df=pd.DataFrame(data)
#En Yüksek Notu Bul
en_yuksek_not=df['Not'].max()
print("En Yuksek Not :",en_yuksek_not)
#Ortalama Notu Hesapla
ortalama_not =df['Not'].mean()
print("Ortalama Not: ",ortalama_not)
print(df.describe())
# Out:
# En Yuksek Not : 100
# Ortalama Not:  87.5
#               Not
# count    4.000000
# mean    87.500000
# std     15.545632
# min     65.000000
# 25%     83.750000
# 50%     92.500000
# 75%     96.250000
# max    100.000000

# %%
import numpy as np
#rastgele tanımlanan değerler - sıralaması olmayan
dizi = np.array ([1,-55,9,-23,13,-21,23,37,29,-6])

#Dizinin ortalama sonuc
ortalama = np.mean(dizi)
print("Ortalama: ",ortalama)

#dizinin standart sapma
std_sapma= np.std(dizi)
print ("Standart Sapma: ",std_sapma)

#dizinin mutlağını al
mutlak_veriler =np.abs(dizi)
print("Mutlak deger cıktısı: ",mutlak_veriler)
# Out:
# Ortalama:  0.7
# Standart Sapma:  26.487921775783015
# Mutlak deger cıktısı:  [ 1 55  9 23 13 21 23 37 29  6]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace (0,10,100)
y = np.sin(x)

plt.plot(x,y)
plt.title ('sinus grafigi')
plt.xlabel('X ekseni')
plt.ylabel('Y ekseni')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
yillar = [2018,2019,2020,2021,2022]
satislar = [150,200,20,-225,14]

#satis grafigini ciz
plt.plot (yillar, satislar,marker='X')
#grafik başlıkları
plt.title("Yıllara göre satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")
#Gragiği göster
plt.show()

# %%
import matplotlib.pyplot as plt
yillar = [2018,2019,2020,2021,2022]
satislar = [150,200,20,-225,14]

#satis grafigini ciz

plt.barh (yillar, satislar,color='skyblue')
#grafik başlıkları
plt.title("Yıllara göre satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")
#Gragiği göster
plt.show()

# %%
import matplotlib.pyplot as plt
yillar = [2018,2019,2020,2021,2022]
satislar = [150,200,20,-225,14]

#satis grafigini ciz

plt.scatter (yillar, satislar,color='red')
#grafik başlıkları
plt.title("Yıllara göre satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")
#Gragiği göster
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

plt.scatter(x,y, c = colors, s=sizes ,alpha = 0.5, cmap='viridis')
plt.title ('Dagılım grafigi')
plt.xlabel('X ekseni')
plt.ylabel('y ekseni')
plt.colorbar() #renk skalasını ekler
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_colormaps():
    colormaps = plt.colormaps()
    n = len(colormaps)
    fig, axs = plt.subplots(n//2, 2, figsize=(10, 2*(n//2)))
    for ax, cmap_name in zip(axs.ravel(), colormaps):
        cmap = plt.get_cmap(cmap_name)
        img = np.linspace(0, 1, 256).reshape(1, -1)
        ax.imshow(img, aspect='auto', cmap=cmap)
        ax.set_title(cmap_name, fontsize=8)
        ax.set_axis_off()
    plt.show()

plot_colormaps()
